# %% [markdown]
# Here’s a clean, complete manual backpropagation implementation in pure NumPy.
#
# It trains a small MLP on the classic XOR problem so you can see every gradient and verify that the network actually learns.
# Key ideas implemented
#
# * Forward pass (linear → activation)
# * Binary cross-entropy loss
# * Full backward pass (chain rule)
# * Gradient descent weight updates
# * Sigmoid activation (easy derivative) + its derivative

# %%
import numpy as np
import matplotlib.pyplot as plt

# Activation function & derivative

def sigmoid(z):
    return 1 / (1 + np.exp(-np.clip(z, -500, 500)))

def sigmoid_derivative(a):
    return a * (1-a)

# Network architecture

np.random.seed(42)

# Layer sizes
n_input = 2
n_hidden = 4
n_output = 1

# Initialisation

W1 = np.random.randn(n_input, n_hidden) 
W1
# Out:
# array([[ 0.49671415, -0.1382643 ,  0.64768854,  1.52302986],
#        [-0.23415337, -0.23413696,  1.57921282,  0.76743473]])
